# %% [markdown]
# <a href="https://colab.research.google.com/github/zekuwany/1_chirps/blob/master/03_export_a_collection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# One of the most commonly asked questions by Earth Engine users is - *How do I download all images in a collection*? The Earth Engine Python API comes with a `ee.batch` module that allows you to launch batch exports and manage tasks. The recommended way to do batch exports like this is to use the Python API's `ee.batch.Export` functions and use a Python for-loop to iterate and export each image. The `ee.batch` module also gives you ability to control *Tasks* - allowing you to automate exports.
#
# > You can also export images in a collection using Javascript API in the Code Editor but this requires you to manually start the tasks for each image. This approach is fine for small number of images. You can check out the [recommended script](https://code.earthengine.google.co.in/?scriptPath=users%2Fujavalgandhi%2FEnd-to-End-GEE%3ASupplement%2FImage_Collections%2FExporting_ImageCollections).

# %% [markdown]
# **#### Initialization**
#
# First of all, you need to run the following cells to initialize the API and authorize your account. You must have a Google Cloud Project associated with your GEE account. Replace the `cloud_project` with your own project from [Google Cloud Console](https://console.cloud.google.com/).

# %%
import ee

#import geemap
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
cloud_project = 'ee-zekuwany'

try:
    ee.Initialize(project=cloud_project)
except:
    ee.Authenticate()
    ee.Initialize(project=cloud_project)

# %% [markdown]
# `**Create a Collection**

# %%
geometry = ee.Geometry.Point([41.73, 9.25])


s2 = ee.ImageCollection('COPERNICUS/S2_HARMONIZED')
rgbVis = {
  'min': 0.0,
  'max': 3000,
  'bands': ['B4', 'B3', 'B2'],
}

filtered = s2 \
  .filter(ee.Filter.date('2019-01-01', '2020-01-01')) \
  .filter(ee.Filter.lt('CLOUDY_PIXEL_PERCENTAGE', 30)) \
  .filter(ee.Filter.bounds(geometry)) \

# Load the Cloud Score+ collection
csPlus = ee.ImageCollection('GOOGLE/CLOUD_SCORE_PLUS/V1/S2_HARMONIZED')
csPlusBands = csPlus.first().bandNames()

# We need to add Cloud Score + bands to each Sentinel-2
# image in the collection
# This is done using the linkCollection() function
filteredS2WithCs = filtered.linkCollection(csPlus, csPlusBands)

# Function to mask pixels with low CS+ QA scores.
def maskLowQA(image):
  qaBand = 'cs'
  clearThreshold = 0.5
  mask = image.select(qaBand).gte(clearThreshold)
  return image.updateMask(mask)

filteredMasked = filteredS2WithCs \
  .map(maskLowQA)

# Write a function that computes NDVI for an image and adds it as a band
def addNDVI(image):
  ndvi = image.normalizedDifference(['B5', 'B4']).rename('ndvi')
  return image.addBands(ndvi)

withNdvi = filteredMasked.map(addNDVI)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ---------------------------------------------------------------------------
# EEException                               Traceback (most recent call last)
# /tmp/ipython-input-550243729.py in <cell line: 0>()
# ----> 1 geometry = ee.Geometry.Point([41.73, 9.25])
#       2
#       3 s2 = ee.ImageCollection('COPERNICUS/S2_HARMONIZED')
#       4 rgbVis = {
#       5   'min': 0.0,
#
# /usr/local/lib/python3.12/dist-packages/ee/geometry.py in Point(coords, proj, *args, **kwargs)
#     206         raise ee_exception.EEException(
#     207             'The Geometry.Point constructor requires 2 coordinates.')
# --> 208     return Geometry(init)
#     209
#     210   @staticmethod
#
# /usr/local/lib/python3.12/dist-packages/ee/computedobject.py in __call__(cls, *args, **kwargs)
#      26       return args[0]
#      27     else:
# ---> 28       return type.__call__(cls, *args, **kwargs)
#      29
#      30
#
# /usr/local/lib/python3.12/dist-packages/ee/_utils.py in wrapper(*args, **kwargs)
#      36           if new_key not in kwargs:
#      37             kwargs[new_key] = old_key_val
# ---> 38       return func(*args, **kwargs)
#      39
#      40     return wrapper
#
# /usr/local/lib/python3.12/dist-packages/ee/geometry.py in __init__(self, geo_json, proj, geodesic, evenOdd)
#      68       EEException: if the given geometry isn't valid.
#      69     """
# ---> 70     self.initialize()
#      71
#      72     # pylint: disable-next=protected-access
#
# /usr/local/lib/python3.12/dist-packages/ee/geometry.py in initialize(cls)
#     164     """Imports API functions to this class."""
#     165     if not cls._initialized:
# --> 166       apifunction.ApiFunction.importApi(cls, cls.name(), cls.name())
#     167       cls._initialized = True
#     168
#
# /usr/local/lib/python3.12/dist-packages/ee/_utils.py in wrapper(*args, **kwargs)
#      36           if new_key not in kwargs:
#      37             kwargs[new_key] = old_key_val
# ---> 38       return func(*args, **kwargs)
#      39
#      40     return wrapper
#
# /usr/local/lib/python3.12/dist-packages/ee/apifunction.py in importApi(cls, target, prefix, type_name, prepend)
#     195         functions.
#     196     """
# --> 197     cls.initialize()
#     198     prepend = prepend or ''
#     199     for name, api_func in cls._api.items():
#
# /usr/local/lib/python3.12/dist-packages/ee/apifunction.py in initialize(cls)
#     159     """Initializes the list of signatures from the Earth Engine front-end."""
#     160     if not cls._api:
# --> 161       signatures = data.getAlgorithms()
#     162       api = {}
#     163       for name, sig in signatures.items():
#
# /usr/local/lib/python3.12/dist-packages/ee/data.py in getAlgorithms()
#    1479   try:
#    1480     call = (
# -> 1481         _get_cloud_projects()
#    1482         .algorithms()
#    1483         .list(parent=_get_projects_path(), prettyPrint=False)
#
# /usr/local/lib/python3.12/dist-packages/ee/data.py in _get_cloud_projects()
#     350 def _get_cloud_projects() -> Any:
#     351   if _cloud_api_resource is None:
# --> 352     raise ee_exception.EEException(_NOT_INITIALIZED_MESSAGE)
#     353   return _cloud_api_resource.projects()
#     354
#
# EEException: Earth Engine client library not initialized. See http://goo.gle/ee-auth.

# %% [markdown]
# ---

# %% [markdown]
# **Export All Images**
#
# Exports are done via the ee.batch module. This module allows you to automatically start an export - making it suitable for batch exports.

# %%
image_ids = withNdvi.aggregate_array('system:index').getInfo()
print('Total images: ', len(image_ids))
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1111893447.py in <cell line: 0>()
# ----> 1 image_ids = withNdvi.aggregate_array('system:index').getInfo()
#       2 print('Total images: ', len(image_ids))
#
# NameError: name 'withNdvi' is not defined

# %% [markdown]
# **Manage Running/Waiting Tasks**
#
# You can manage tasks as well. Get a list of tasks and get state information on *them*

# %%
tasks = ee.batch.Task.list()
for task in tasks:
  task_id = task.status()['id']
  task_state = task.status()['state']
  print(task_id, task_state)

# %% [markdown]
# **You can cancel tasks as well**

# %%
tasks = ee.batch.Task.list()
for task in tasks:
    task_id = task.status()['id']
    task_state = task.status()['state']
    if task_state == 'RUNNING' or task_state == 'READY':
        task.cancel()
        print('Task {} canceled'.format(task_id))
    else:
        print('Task {} state is {}'.format(task_id, task_state))
